# %% [markdown]
# <a href="https://colab.research.google.com/github/eclipsy739/menubordi/blob/main/menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread gspread_dataframe oauth2client

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-065d76e1-d4a0-461c-a145-71a65b37d80a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-065d76e1-d4a0-461c-a145-71a65b37d80a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
spreadsheet = client.open_by_key("1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg")
for s in spreadsheet.worksheets():
    print(s.title)
# Out:
# Лист1

# %%
sheet = client.open_by_key("1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg").worksheet("Лист1")

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Указываем доступные области
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]

creds = ServiceAccountCredentials.from_json_keyfile_name("menu-462012-6490844303b5.json", scope)
client = gspread.authorize(creds)

# Подключаемся к таблице по ID
spreadsheet_id = "1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg"
sheet = client.open_by_key(spreadsheet_id).worksheet("Лист1")

# %%
data = sheet.get_all_records()
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#    ID   Название Категории  Цена
# 0   1  Американо      Кофе  200р
# 1   2       Борщ       Суп  300р
# 2   3    Чизкейк    Десерт  220р
# 3   4  Брускетта   Закуски  210р
# 4   5    Спешиал    Бургер  299р

# %%
new_row = ['123', 'Бургер', 'Фастфуд', '299']
sheet.append_row(new_row)
# Out:
# {'spreadsheetId': '1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg',
#  'tableRange': "'Лист1'!A3:D12",
#  'updates': {'spreadsheetId': '1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg',
#   'updatedRange': "'Лист1'!A13:D13",
#   'updatedRows': 1,
#   'updatedColumns': 4,
#   'updatedCells': 4}}

# %%
sheet.batch_clear(['A2:D2'])
# Out:
# {'spreadsheetId': '1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg',
#  'clearedRanges': ["'Лист1'!A2:D2"]}

# %%
sheet.batch_clear(['A13:D13'])
# Out:
# {'spreadsheetId': '1IdLgdihDv0wXT6oI0NCCwzoU0JZ6wcBwRhkq04NUnsg',
#  'clearedRanges': ["'Лист1'!A13:D13"]}
